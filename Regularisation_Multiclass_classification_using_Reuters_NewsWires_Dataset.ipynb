# %% [markdown]
# <a href="https://colab.research.google.com/github/Satwikamurakonda/Deep-Learning/blob/main/Regularisation_Multiclass_classification_using_Reuters_NewsWires_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np

# %%
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 [==============================] - 0s 0us/step

# %%
import numpy as np
from keras.utils import to_categorical

def OneHotEncoding_fn(ReutersData, dimension=10000):
    # 8982 x 10k matrix of zeros
    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):
        #Selectively make indices as 1 based on availability of word in the review.
        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data

x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
from keras import models
from keras import layers

model = models.Sequential()
model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]

# %%
model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 2s 69ms/step - loss: 2.8172 - categorical_accuracy: 0.5216 - val_loss: 1.8693 - val_categorical_accuracy: 0.6400
# Epoch 2/25
# 16/16 [==============================] - 1s 50ms/step - loss: 1.5783 - categorical_accuracy: 0.6990 - val_loss: 1.3619 - val_categorical_accuracy: 0.7075
# Epoch 3/25
# 16/16 [==============================] - 1s 49ms/step - loss: 1.1826 - categorical_accuracy: 0.7523 - val_loss: 1.1912 - val_categorical_accuracy: 0.7387
# Epoch 4/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.9637 - categorical_accuracy: 0.7977 - val_loss: 1.0837 - val_categorical_accuracy: 0.7613
# Epoch 5/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.8029 - categorical_accuracy: 0.8291 - val_loss: 1.0156 - val_categorical_accuracy: 0.7962
# Epoch 6/25
# 16/16 [==============================] - 1s 51ms/step - loss: 0.6715 - categorical_accuracy: 0.8572 - val_loss: 0.9701 - val_categorical_accuracy: 0.8050
# Epoch 7/25
# 16/16 [==============================] - 1s 51ms/step - loss: 0.5649 - categorical_accuracy: 0.8834 - val_loss: 0.9607 - val_categorical_accuracy: 0.7912
# Epoch 8/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.4797 - categorical_accuracy: 0.8986 - val_loss: 0.9338 - val_categorical_accuracy: 0.8125
# Epoch 9/25
# 16/16 [==============================] - 1s 51ms/step - loss: 0.4113 - categorical_accuracy: 0.9107 - val_loss: 0.9231 - val_categorical_accuracy: 0.8075
# Epoch 10/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.3502 - categorical_accuracy: 0.9239 - val_loss: 0.9190 - val_categorical_accuracy: 0.8062
# Epoch 11/25
# 16/16 [==============================] - 1s 73ms/step - loss: 0.3056 - categorical_accuracy: 0.9333 - val_loss: 0.9082 - val_categorical_accuracy: 0.8050
# Epoch 12/25
# 16/16 [==============================] - 1s 83ms/step - loss: 0.2670 - categorical_accuracy: 0.9408 - val_loss: 0.9094 - val_categorical_accuracy: 0.8138
# Epoch 13/25
# 16/16 [==============================] - 1s 70ms/step - loss: 0.2385 - categorical_accuracy: 0.9452 - val_loss: 0.9271 - val_categorical_accuracy: 0.8138
# Epoch 14/25
# 16/16 [==============================] - 1s 65ms/step - loss: 0.2144 - categorical_accuracy: 0.9496 - val_loss: 0.9211 - val_categorical_accuracy: 0.8150
# Epoch 15/25
# 16/16 [==============================] - 1s 90ms/step - loss: 0.1937 - categorical_accuracy: 0.9512 - val_loss: 0.9340 - val_categorical_accuracy: 0.8087
# Epoch 16/25
# 16/16 [==============================] - 1s 82ms/step - loss: 0.1748 - categorical_accuracy: 0.9537 - val_loss: 0.9705 - val_categorical_accuracy: 0.8037
# Epoch 17/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1634 - categorical_accuracy: 0.9539 - val_loss: 0.9580 - val_categorical_accuracy: 0.8075
# Epoch 18/25
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1545 - categorical_accuracy: 0.9553 - val_loss: 0.9918 - val_categorical_accuracy: 0.8100
# Epoch 19/25
# 16/16 [==============================] - 1s 47ms/step - loss: 0.1469 - categorical_accuracy: 0.9556 - val_loss: 1.0035 - val_categorical_accuracy: 0.8050
# Epoch 20/25
# 16/16 [==============================] - 1s 48ms/step - loss: 0.1398 - categorical_accuracy: 0.9561 - val_loss: 1.0418 - val_categorical_accuracy: 0.8050
# Epoch 21/25
# 16/16 [==============================] - 1s 50ms/step - loss: 0.1341 - categorical_accuracy: 0.9567 - val_loss: 1.0319 - val_categorical_accuracy: 0.8062
# Epoch 22/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1294 - categorical_accuracy: 0.9577 - val_loss: 1.0396 - val_categorical_accuracy: 0.8012
# Epoch 23/25
# 16/16 [==============================] - 1s 49ms/step - loss: 0.1265 - categorical_accuracy: 0.9560 - val_loss: 1.0551 - val_categorical_accuracy: 0.8050
# Epoch 24/25
# 16/16 [==============================] - 1s 58ms/step - loss: 0.1234 - categorical_accuracy: 0.9567 - val_loss: 1.0485 - val_categorical_accuracy: 0.8037
# Epoch 25/25
# 16/16 [==============================] - 1s 82ms/step - loss: 0.1189 - categorical_accuracy: 0.9576 - val_loss: 1.0550 - val_categorical_accuracy: 0.7987

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
