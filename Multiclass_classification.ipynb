# %% [markdown]
# <a href="https://colab.research.google.com/github/Satwikamurakonda/Deep-Learning/blob/main/Multiclass_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from keras.datasets import reuters

# %%
(train_X, train_Y), (test_X, test_Y) = reuters.load_data(num_words=10000)

# %%
import numpy as np
from keras.utils import to_categorical

def OneHotEncoding_fn(ReutersData, dimension=10000):
    # 8982 x 10k matrix of zeros
    OneHotEncoded_Data = np.zeros((len(ReutersData), dimension))
    for i, sequence in enumerate(ReutersData):
        #Selectively make indices as 1 based on availability of word in the review.
        OneHotEncoded_Data[i, sequence] = 1.
    return OneHotEncoded_Data

x_train = OneHotEncoding_fn(train_X)
x_test = OneHotEncoding_fn(test_X)

y_train = to_categorical(train_Y)
y_test = to_categorical(test_Y)

# %%
from keras import models
from keras import layers
from keras import regularizers

model = models.Sequential()
#model.add(layers.Dense(64, activation='relu', input_shape=(10000,)))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l1(0.001), activation='relu', input_shape=(10000,)))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.01), activation='relu', input_shape=(10000,)))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu', input_shape=(10000,)))

#model.add(layers.Dense(64, activation='relu'))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l1(0.001), activation='relu'))
#model.add(layers.Dense(64, kernel_regularizer=regularizers.l2(0.01), activation='relu'))
model.add(layers.Dense(64, kernel_regularizer=regularizers.l1_l2(l1=0.001, l2=0.01), activation='relu'))

model.add(layers.Dense(46, activation='softmax'))

# %%
from keras import optimizers
from keras import losses
from keras import metrics

X_validation = x_train[:800]
X_train_without_val = x_train[800:]
y_validation = y_train[:800]
y_train_without_val = y_train[800:]


model.compile(optimizer=optimizers.RMSprop(learning_rate=0.001, rho=0.9),
             loss=losses.categorical_crossentropy,
             metrics=[metrics.categorical_accuracy])

history = model.fit(X_train_without_val,
                    y_train_without_val,
                    epochs=25,
                    batch_size=512,
                    validation_data=(X_validation,y_validation))
# Out:
# Epoch 1/25
# 16/16 [==============================] - 2s 80ms/step - loss: 7.3715 - categorical_accuracy: 0.4548 - val_loss: 3.9331 - val_categorical_accuracy: 0.5437
# Epoch 2/25
# 16/16 [==============================] - 1s 55ms/step - loss: 3.5396 - categorical_accuracy: 0.5420 - val_loss: 3.2191 - val_categorical_accuracy: 0.5763
# Epoch 3/25
# 16/16 [==============================] - 1s 55ms/step - loss: 3.1034 - categorical_accuracy: 0.5725 - val_loss: 2.9128 - val_categorical_accuracy: 0.5900
# Epoch 4/25
# 16/16 [==============================] - 1s 84ms/step - loss: 2.8800 - categorical_accuracy: 0.6106 - val_loss: 2.7373 - val_categorical_accuracy: 0.6162
# Epoch 5/25
# 16/16 [==============================] - 1s 93ms/step - loss: 2.7300 - categorical_accuracy: 0.6343 - val_loss: 2.6102 - val_categorical_accuracy: 0.6675
# Epoch 6/25
# 16/16 [==============================] - 1s 68ms/step - loss: 2.6054 - categorical_accuracy: 0.6594 - val_loss: 2.5065 - val_categorical_accuracy: 0.6550
# Epoch 7/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.5153 - categorical_accuracy: 0.6641 - val_loss: 2.4224 - val_categorical_accuracy: 0.6750
# Epoch 8/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.4236 - categorical_accuracy: 0.6813 - val_loss: 2.3605 - val_categorical_accuracy: 0.6750
# Epoch 9/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.3626 - categorical_accuracy: 0.6831 - val_loss: 2.2826 - val_categorical_accuracy: 0.6850
# Epoch 10/25
# 16/16 [==============================] - 1s 50ms/step - loss: 2.2975 - categorical_accuracy: 0.6872 - val_loss: 2.2450 - val_categorical_accuracy: 0.6850
# Epoch 11/25
# 16/16 [==============================] - 1s 51ms/step - loss: 2.2475 - categorical_accuracy: 0.6896 - val_loss: 2.2032 - val_categorical_accuracy: 0.6875
# Epoch 12/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.2032 - categorical_accuracy: 0.6924 - val_loss: 2.1531 - val_categorical_accuracy: 0.6913
# Epoch 13/25
# 16/16 [==============================] - 1s 54ms/step - loss: 2.1646 - categorical_accuracy: 0.6949 - val_loss: 2.1395 - val_categorical_accuracy: 0.6988
# Epoch 14/25
# 16/16 [==============================] - 1s 53ms/step - loss: 2.1381 - categorical_accuracy: 0.6947 - val_loss: 2.1117 - val_categorical_accuracy: 0.6888
# Epoch 15/25
# 16/16 [==============================] - 1s 55ms/step - loss: 2.1136 - categorical_accuracy: 0.6949 - val_loss: 2.0780 - val_categorical_accuracy: 0.6963
# Epoch 16/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.0886 - categorical_accuracy: 0.6981 - val_loss: 2.0740 - val_categorical_accuracy: 0.7025
# Epoch 17/25
# 16/16 [==============================] - 1s 52ms/step - loss: 2.0666 - categorical_accuracy: 0.6987 - val_loss: 2.0505 - val_categorical_accuracy: 0.7000
# Epoch 18/25
# 16/16 [==============================] - 1s 81ms/step - loss: 2.0452 - categorical_accuracy: 0.7003 - val_loss: 2.0165 - val_categorical_accuracy: 0.6975
# Epoch 19/25
# 16/16 [==============================] - 1s 92ms/step - loss: 2.0320 - categorical_accuracy: 0.7008 - val_loss: 2.0256 - val_categorical_accuracy: 0.6925
# Epoch 20/25
# 16/16 [==============================] - 1s 73ms/step - loss: 2.0243 - categorical_accuracy: 0.7009 - val_loss: 2.0075 - val_categorical_accuracy: 0.7000
# Epoch 21/25
# 16/16 [==============================] - 1s 53ms/step - loss: 1.9982 - categorical_accuracy: 0.7012 - val_loss: 1.9771 - val_categorical_accuracy: 0.7013
# Epoch 22/25
# 16/16 [==============================] - 1s 50ms/step - loss: 1.9883 - categorical_accuracy: 0.7031 - val_loss: 1.9708 - val_categorical_accuracy: 0.7013
# Epoch 23/25
# 16/16 [==============================] - 1s 53ms/step - loss: 1.9731 - categorical_accuracy: 0.7046 - val_loss: 1.9553 - val_categorical_accuracy: 0.7050
# Epoch 24/25
# 16/16 [==============================] - 1s 53ms/step - loss: 1.9633 - categorical_accuracy: 0.7003 - val_loss: 1.9500 - val_categorical_accuracy: 0.7063
# Epoch 25/25
# 16/16 [==============================] - 1s 52ms/step - loss: 1.9492 - categorical_accuracy: 0.7048 - val_loss: 1.9368 - val_categorical_accuracy: 0.7063

# %%
import matplotlib.pyplot as plt

history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'g--', label='Training loss')
plt.plot(epochs, val_loss_values, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
plt.clf()
acc_values = history_dict['categorical_accuracy']
val_acc_values = history_dict['val_categorical_accuracy']
plt.plot(epochs, acc_values, 'g--', label='Training Accuracy')
plt.plot(epochs, val_acc_values, 'r', label='Validation Accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
